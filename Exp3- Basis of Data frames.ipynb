# %% [markdown]
# # Basics of Data Frame

# %%
# Exp: 3

# %%
# Aim : Basics of Data Frame

# %%
# Name: Rushikesh Nilkhan
# Roll no: 43
# Section: B
# Subject: ET1

# %%
# Basics of Data Frame

# %% [markdown]
# # Creating a Series

# %%
# Importing the pandas library
import pandas as pd

# %%
Friends=["Om", "Shahid", "Ansh", "Rushi", "Jay"]

# %%
Friends
# Out:
# ['Om', 'Shahid', 'Ansh', 'Rushi', 'Jay']

# %%
rollList = pd.Series(Friends, index=[20,57,40,43,26])

# %%
rollList
# Out:
# 20        Om
# 57    Shahid
# 40      Ansh
# 43     Rushi
# 26       Jay
# dtype: object

# %% [markdown]
# # Creating a Data Frame

# %%
df = pd.DataFrame([[27, 15, 10, 5],[2, 10, 18, 22],[15, 26, 0, 20],[7, 11, 13, 20]],
                        columns = ["CD","DSS","DBMS","CAO"]
                        )

# %%
df
# Out:
#    CD  DSS  DBMS  CAO
# 0  27   15    10    5
# 1   2   10    18   22
# 2  15   26     0   20
# 3   7   11    13   20

# %%
df.shape
# Out:
# (4, 4)

# %%
df.size
# Out:
# 16

# %%
df.ndim
# Out:
# 2

# %%
df2 = pd.DataFrame([[27, 10, 11, 0]],
                        columns = ["CD","DSS","DBMS","CAO"]
                        )

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
df3
# Out:
#    CD  DSS  DBMS  CAO
# 0  27   15    10    5
# 1   2   10    18   22
# 2  15   26     0   20
# 3   7   11    13   20
# 4  27   10    11    0

# %% [markdown]
# # Adding Record (Columns) to Data Frame

# %%
df3["DM"]=[12, 18, 2, 8, 11]

# %%
df3
# Out:
#    CD  DSS  DBMS  CAO  DM
# 0  27   15    10    5  12
# 1   2   10    18   22  18
# 2  15   26     0   20   2
# 3   7   11    13   20   8
# 4  27   10    11    0  11

# %% [markdown]
# # Deleting Record (Row) From Data Frame

# %%
df4= df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DSS  DBMS  CAO  DM
# 0  27   15    10    5  12
# 2  15   26     0   20   2
# 3   7   11    13   20   8
# 4  27   10    11    0  11

# %%
print("Mean of DSS:", df4["DSS"].mean())
# Out:
# Mean of DSS: 15.5

# %%
print("Mean of DSS:", df4["DSS"].median())
# Out:
# Mean of DSS: 13.0

# %%
print("Mean of DSS:", df4["DSS"].mode())
# Out:
# Mean of DSS: 0    10
# 1    11
# 2    15
# 3    26
# Name: DSS, dtype: int64
